# %%
import kaggle
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression as LR
from sklearn.preprocessing import StandardScaler,LabelEncoder,PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\Users\vamsi\Desktop\champs-scalar-coupling\train.csv")
df2=pd.read_csv(r"C:\Users\vamsi\Desktop\champs-scalar-coupling\test.csv")

# %%
df3=df2['id']

# %%
dummy=LabelEncoder()
df['type']=dummy.fit_transform(df['type'].astype(str))
df2['type']=dummy.fit_transform(df2['type'].astype(str))
df.columns
# Out:
# Index(['id', 'molecule_name', 'atom_index_0', 'atom_index_1', 'type',
#        'scalar_coupling_constant'],
#       dtype='object')

# %%
df2.shape
# Out:
# (2505542, 5)

# %%
x=df[['atom_index_0', 'atom_index_1', 'type']]
y=df[['scalar_coupling_constant']]
xtrain,xtest,ytrain,ytest=train_test_split(polyx,y,test_size=0.3)

# %%
model=LR()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
import math
math.sqrt(mean_squared_error(ytest,model.predict(xtest)))
# Out:
# 26.80286889752211

# %%
nood=model.predict(df2[['atom_index_0', 'atom_index_1', 'type']])

# %%
nood.shape
# Out:
# (2505542, 1)

# %%
noob=pd.DataFrame(nood)

# %%
new=pd.DataFrame(df2['id'])

# %%
new['scalar_coupling_constant']=noob

# %%
new
# Out:
#               id  scalar_coupling_constant
# 0        4658147                 31.552442
# 1        4658148                 52.785946
# 2        4658149                -10.934424
# 3        4658150                 52.796681
# 4        4658151                 31.555234
# 5        4658152                 52.796681
# 6        4658153                 -0.304951
# 7        4658154                 20.924581
# 8        4658155                 20.920609
# 9        4658156                 52.803444
# 10       4658157                 -0.298188
# 11       4658158                 20.927372
# 12       4658159                 52.810207
# 13       4658160                 -0.291426
# 14       4658161                 -0.276719
# 15       4658162                 52.809027
# 16       4658163                 20.932955
# 17       4658164                 20.928983
# 18       4658165                 -0.269956
# 19       4658166                 52.815790
# 20       4658167                 20.935746
# ...

# %%
new.to_csv(r"C:\Users\vamsi\Desktop\champs-scalar-coupling\my_1'st_Kaggle.csv",index=False)
